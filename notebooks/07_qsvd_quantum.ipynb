# %% [markdown]
# # 07 - Quantum-Inspired Simulation
#
# Use compact latent factors and Qiskit statevectors when available.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import prepare_data
from src.quantum_model import QuantumInspiredRecommender

data = prepare_data(sample_users=200)
model = QuantumInspiredRecommender(n_factors=4).fit(data.ratings, data.movies)
print('Qiskit available:', model.qiskit_available)
model.recommend(user_id=int(data.users.user_id.iloc[0]), top_n=5)
