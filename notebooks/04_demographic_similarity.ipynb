# %% [markdown]
# # 04 - Demographic Similarity
#
# Recommend movies for cold-start users using demographics.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import prepare_data
from src.demographic_similarity import DemographicRecommender

data = prepare_data(sample_users=300)
model = DemographicRecommender().fit(data.ratings, data.users, data.movies)
model.recommend(profile={'gender': 'F', 'age': 18, 'occupation': 4}, top_n=5)
