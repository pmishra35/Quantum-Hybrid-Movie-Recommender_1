# %% [markdown]
# # 02 - Preprocessing
#
# Clean data and create processed CSV files.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import prepare_data, save_processed_data

data = prepare_data(raw_dir='../data/raw/ml-1m', sample_users=500)
save_processed_data(data, '../data/processed')
data.ratings.head(), data.users.head(), data.user_item_matrix.shape
