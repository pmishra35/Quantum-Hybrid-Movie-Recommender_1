# %% [markdown]
# # 06 - Classical SVD
#
# Train low-rank matrix factorization for sparse ratings.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import prepare_data
from src.svd_model import SVDRecommender

data = prepare_data(sample_users=300)
model = SVDRecommender(n_factors=20).fit(data.ratings, data.movies)
model.recommend(user_id=int(data.users.user_id.iloc[0]), top_n=5)
