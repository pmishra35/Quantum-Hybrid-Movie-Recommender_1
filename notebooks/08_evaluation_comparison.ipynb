# %% [markdown]
# # 08 - Evaluation Comparison
#
# Run the full pipeline and inspect model metrics.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from argparse import Namespace
from run_pipeline import run_pipeline

args = Namespace(raw_dir=Path('../data/raw/ml-1m'), sample_users=300, alpha=0.5, top_k=5, test_fraction=0.2, max_eval_users=40, random_state=42)
run_pipeline(args)
