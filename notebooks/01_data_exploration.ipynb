# %% [markdown]
# # 01 - Data Exploration
#
# Explore MovieLens 1M movies, ratings, users, and sparsity.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import load_raw_data

movies, ratings, users = load_raw_data('../data/raw/ml-1m')
movies.head(), ratings.head(), users.head()

# %%
summary = {
    'movies': movies['movie_id'].nunique(),
    'users': users['user_id'].nunique(),
    'ratings': len(ratings),
    'sparsity': 1 - len(ratings) / (users['user_id'].nunique() * movies['movie_id'].nunique())
}
summary
