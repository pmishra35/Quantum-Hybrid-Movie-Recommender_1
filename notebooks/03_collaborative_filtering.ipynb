# %% [markdown]
# # 03 - Collaborative Filtering
#
# Train user-based collaborative filtering and generate recommendations.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))

from src.preprocessing import prepare_data
from src.collaborative_filtering import CollaborativeFilteringRecommender

data = prepare_data(sample_users=300)
model = CollaborativeFilteringRecommender().fit(data.ratings, data.movies)
model.recommend(user_id=int(data.users.user_id.iloc[0]), top_n=5)
